# %% [markdown]
# # Análisis de regresión

# %%
import numpy as np
import pandas as pd
import cufflinks as cf
from sklearn.impute import SimpleImputer
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.feature_selection import SelectKBest, f_classif, f_regression
from sklearn.metrics import accuracy_score, roc_auc_score, mean_absolute_error, r2_score

cf.go_offline()
pd.set_option("display.max_columns", 50)
pd.set_option('display.float_format', lambda x: "{:,.2f}".format(x))
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.11.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Funciones relevantes

# %%
def normalize_content(texto):
    if texto in ['G', 'TV-G']:
        return "Publico General"
    if texto in ['R', 'NC-17', 'X']:
        return "Restricted"
    if texto in ['M', 'PG', 'GP', 'PG-13','TV-PG','TV-14'] :
        return "Parental Guiadance"
    if texto in ['Approved', 'Passed']:
        return "Approved"
    if texto in ['Not Rated', 'Unrated']:
        return "Not Rated"

# %%
def plot_histogram(df, feature):
    return df[[feature]].iplot(kind="hist", title = f"{feature} histogram", colors=["#296EAA"])

# %% [markdown]
# ## Carga de datos

# %%
df = pd.read_csv("../data/movies.csv")

# %%
df.shape
# Out:
# (5043, 16)

# %%
df.sample(5)
# Out:
#                 movie_title  \
# 3632           The Kingdom
# 2081  Domestic Disturbance
# 1596                  Hero
# 2492          The Ring Two
# 1274           The Tempest
#
#                                         movie_imdb_link             color  \
# 3632  http://www.imdb.com/title/tt0431197/?ref_=fn_t...             Color
# 2081  http://www.imdb.com/title/tt0249478/?ref_=fn_t...             Color
# 1596  http://www.imdb.com/title/tt0299977/?ref_=fn_t...   Black and White
# 2492  http://www.imdb.com/title/tt0377109/?ref_=fn_t...             Color
# 1274  http://www.imdb.com/title/tt1274300/?ref_=fn_t...             Color
#
#       genre_4  duration         gross genre_1    genre_2   genre_3  \
# 3632      NaN    110.00 47,456,450.00  Action      Drama  Thriller
# 2081      NaN     89.00           NaN   Crime    Mystery  Thriller
# 1596      NaN     80.00     84,961.00  Action  Adventure   History
# 2492      NaN    128.00 75,888,270.00  Horror    Mystery       NaN
# 1274  Romance    110.00           NaN  Comedy      Drama   Fantasy
#
#      num_voted_users facenumber_in_poster  language country content_rating  \
# 3632          101386                    1   English     USA              R
# 2081           21283                    1   English     USA          PG-13
# 1596          149414                    4  Mandarin   China          PG-13
# 2492           71153                    0   English     USA          PG-13
# 1274            6147                    2   English     USA          PG-13
#
#       title_year  imdb_score
# 3632    2,007.00        7.10
# 2081    2,001.00        5.50
# 1596    2,002.00        7.90
# 2492    2,005.00        5.40
# 1274    2,010.00        5.40

# %% [markdown]
# ## Análisis exploratorio

# %%
ls_disc = ["color", "genre_4", "genre_1", "genre_2", "genre_3", "language", "country", "content_rating"]
ls_cont = ["duration", "gross", "num_voted_users", "facenumber_in_poster", "title_year"]
target = "imdb_score"

# %%
plot_histogram(df=df, feature=target)
# Out:
# <div>                            <div id="0e136735-8bd6-405d-ae46-8d3e0dd3d8c0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("0e136735-8bd6-405d-ae46-8d3e0dd3d8c0")) {                    Plotly.newPlot(                        "0e136735-8bd6-405d-ae46-8d3e0dd3d8c0",                        [{"histfunc":"count","histnorm":"","marker":{"color":"rgba(41, 110, 170, 1.0)","line":{"color":"#4D5663","width":1.3}},"name":
.4,6.9,6.9,6.7,6.1,6.5,6.0,6.1,7.2,6.2,6.7,8.1,5.0,5.6,6.7,8.5,4.2,6.0,6.3,5.9,4.7,6.4,5.6,6.8,7.1,6.2,4.9,7.2,5.3,6.5,6.2,3.5,6.5,6.3,6.2,6.7,8.0,7.0,6.2,7.4,7.2,6.0,6.8,4.6,5.8,7.3,6.2,4.7,7.2,6.0,4.8,6.7,6.4,5.1,4.8,5.7,4.6,7.7,7.9,4.0,6.4,4.8,5.8,7.4,7.4,6.8,6.9,5.9,6.9,4.5,6.0,7.0,6.8,6.3,6.7,6.8,4.8,6.1,6.0,5.4,6.9,6.4,6.3,5.5,6.3,7.2,7.1,6.3,7.6,7.2,6.3,4.0,8.0,7.4,5.8,7.1,6.9,7.8,5.9,7.3,6.7,7.0,6.5,6.5,5.7,8.0,8.3,5.7,5.8,7.3,7.7,8.1,7.2,5.8,7.7,4.1,8.3,4.9,6.9,8.2,5.3,7.0,2.7,6.3,6.7,5.6,5.2,6.8,7.3,6.4,7.0,6.7,5.5,6.1,7.0,8.5,5.0,6.0,7.1,8.0,7.1, ...

# %%
df[ls_cont+[target]].describe(percentiles = [0.1, 0.5, 0.95, 0.99])
# Out:
#        duration          gross  title_year  imdb_score
# count  5,028.00       1,505.00    4,935.00    5,043.00
# mean     107.20  47,523,599.37    2,042.59        6.46
# std       25.20  70,034,507.15    2,818.52        1.71
# min        7.00         721.00    1,916.00        1.60
# 10%       86.00     335,377.20    1,988.00        5.00
# 50%      103.00  24,792,061.00    2,005.00        6.60
# 95%      146.00 177,159,421.40    2,015.00        8.10
# 99%      189.00 336,530,303.00    2,016.00        8.50
# max      511.00 760,505,847.00  200,000.00       98.00

# %%
df[df["gross"] >= 7.6*10**8]
# Out:
#      movie_title                                    movie_imdb_link  color  \
# 4425     Avatar   http://www.imdb.com/title/tt0499549/?ref_=fn_t...  Color
#
#      genre_4  duration          gross genre_1    genre_2  genre_3  \
# 4425  Sci-Fi    178.00 760,505,847.00  Action  Adventure  Fantasy
#
#      num_voted_users facenumber_in_poster language country content_rating  \
# 4425          886204                    0  English     USA          PG-13
#
#       title_year  imdb_score
# 4425    2,009.00        7.90

# %%
df[df[target] == 98]
# Out:
#      movie_title                                movie_imdb_link  color  \
# 3319   Sanctuary  nudity|party|pirate|swimsuit|three word title  Color
#
#      genre_4  duration  gross genre_1 genre_2   genre_3      num_voted_users  \
# 3319     NaN     82.00    NaN  Comedy  Horror  Thriller   Quite a Conundrum
#
#      facenumber_in_poster language  country content_rating  title_year  \
# 3319           John Lucas        8  English            USA  200,000.00
#
#       imdb_score
# 3319       98.00

# %%
df = df[df[target] != 98].reset_index(drop = True)

# %%
df["num_voted_users"] = df["num_voted_users"].astype(float)

# %%
df[ls_cont+[target]].describe(percentiles = [0.1, 0.5, 0.95, 0.99])
# Out:
#        duration          gross  num_voted_users  title_year  imdb_score
# count  5,027.00       1,505.00         5,042.00    4,934.00    5,042.00
# mean     107.21  47,523,599.37        83,684.73    2,002.47        6.44
# std       25.20  70,034,507.15       138,493.99       12.48        1.13
# min        7.00         721.00             5.00    1,916.00        1.60
# 10%       86.00     335,377.20         1,649.70    1,988.00        5.00
# 50%      103.00  24,792,061.00        34,371.00    2,005.00        6.60
# 95%      146.00 177,159,421.40       332,265.45    2,015.00        8.09
# 99%      189.00 336,530,303.00       681,112.44    2,016.00        8.50
# max      511.00 760,505,847.00     1,689,764.00    2,016.00        9.50

# %%
for col in ls_disc:
    display(df[col].value_counts(True).reset_index())
# Out:
#               index  color
# 0             Color   0.96
# 1   Black and White   0.04
#        index  genre_4
# 0   Thriller     0.34
# 1    Romance     0.13
# 2     Family     0.10
# 3     Sci-Fi     0.08
# 4    Fantasy     0.07
# 5    Mystery     0.05
# 6        War     0.04
# 7      Drama     0.04
# 8      Sport     0.03
# 9    History     0.03
# 10   Musical     0.02
# 11     Music     0.02
# 12   Western     0.02
# 13    Comedy     0.02
# 14    Horror     0.01
# 15     Crime     0.01
# 16      News     0.00
#           index  genre_1
# 0        Comedy     0.26
# 1        Action     0.23
# 2         Drama     0.19
# 3     Adventure     0.09
# 4         Crime     0.07
# 5     Biography     0.05
# 6        Horror     0.05
# 7   Documentary     0.02
# 8     Animation     0.01
# 9       Fantasy     0.01
# 10      Mystery     0.01
# 11     Thriller     0.00
# 12       Sci-Fi     0.00
# 13      Western     0.00
# 14       Family     0.00
# 15      Romance     0.00
# 16      Musical     0.00
# 17        Music     0.00
# 18    Game-Show     0.00
# 19      History     0.00
# 20    Film-Noir     0.00
#           index  genre_2
# 0         Drama     0.27
# 1     Adventure     0.11
# 2         Crime     0.09
# 3       Romance     0.09
# 4        Comedy     0.08
# 5        Horror     0.05
# 6      Thriller     0.05
# 7       Mystery     0.05
# 8        Family     0.04
# 9       Fantasy     0.04
# 10    Animation     0.03
# 11       Sci-Fi     0.03
# 12        Music     0.02
# 13      History     0.02
# 14        Sport     0.01
# 15    Biography     0.01
# 16          War     0.01
# 17      Musical     0.01
# 18  Documentary     0.01
# 19      Western     0.00
# 20    Film-Noir     0.00
# 21        Short     0.00
# 22   Reality-TV     0.00
# 23         News     0.00
#           index  genre_3
# 0      Thriller     0.18
# 1       Romance     0.15
# 2         Drama     0.12
# 3        Sci-Fi     0.09
# 4       Fantasy     0.07
# 5        Family     0.06
# 6        Comedy     0.06
# 7       Mystery     0.06
# 8         Crime     0.04
# 9        Horror     0.03
# 10      History     0.03
# 11        Music     0.03
# 12        Sport     0.03
# 13          War     0.02
# 14      Musical     0.01
# 15    Animation     0.01
# 16      Western     0.01
# 17  Documentary     0.00
# 18    Biography     0.00
# 19        Short     0.00
# 20    Film-Noir     0.00
# 21   Reality-TV     0.00
# 22         News     0.00
#          index  language
# 0      English      0.93
# 1       French      0.01
# 2      Spanish      0.01
# 3        Hindi      0.01
# 4     Mandarin      0.01
# 5       German      0.00
# 6     Japanese      0.00
# 7      Russian      0.00
# 8      Italian      0.00
# 9    Cantonese      0.00
# 10      Korean      0.00
# 11  Portuguese      0.00
# 12      Danish      0.00
# 13      Hebrew      0.00
# 14     Swedish      0.00
# 15      Arabic      0.00
# 16   Norwegian      0.00
# 17       Dutch      0.00
# 18      Polish      0.00
# 19     Persian      0.00
# 20        Thai      0.00
# 21     Chinese      0.00
# 22    Romanian      0.00
# 23        None      0.00
# 24  Indonesian      0.00
# 25  Aboriginal      0.00
# 26        Dari      0.00
# 27   Icelandic      0.00
# 28        Zulu      0.00
# 29     Kannada      0.00
# 30       Greek      0.00
# 31     Swahili      0.00
# 32   Hungarian      0.00
# 33     Bosnian      0.00
# 34     Aramaic      0.00
# 35       Czech      0.00
# 36        Urdu      0.00
# 37    Dzongkha      0.00
# 38        Maya      0.00
# 39    Filipino      0.00
# 40      Telugu      0.00
# 41   Slovenian      0.00
# 42      Kazakh      0.00
# 43  Vietnamese      0.00
# 44     Panjabi      0.00
# 45       Tamil      0.00
# 46   Mongolian      0.00
#            index  country
# 0            USA     0.76
# 1             UK     0.09
# 2         France     0.03
# 3         Canada     0.03
# 4        Germany     0.02
# ..           ...      ...
# 60    Kyrgyzstan     0.00
# 61         Egypt     0.00
# 62   Afghanistan     0.00
# 63  Soviet Union     0.00
# 64      Cameroon     0.00
#
# [65 rows x 2 columns]
#         index  content_rating
# 0           R            0.45
# 1       PG-13            0.31
# 2          PG            0.15
# 3   Not Rated            0.02
# 4           G            0.02
# 5     Unrated            0.01
# 6    Approved            0.01
# 7       TV-14            0.01
# 8       TV-MA            0.00
# 9           X            0.00
# 10      TV-PG            0.00
# 11       TV-G            0.00
# 12     Passed            0.00
# 13      NC-17            0.00
# 14         GP            0.00
# 15          M            0.00
# 16       TV-Y            0.00
# 17      TV-Y7            0.00

# %%
df[ls_cont+ls_disc].isnull().sum() / len(df)
# Out:
# duration               0.00
# gross                  0.70
# num_voted_users        0.00
# facenumber_in_poster   0.00
# title_year             0.02
# color                  0.00
# genre_4                0.72
# genre_1                0.00
# genre_2                0.13
# genre_3                0.39
# language               0.00
# country                0.00
# content_rating         0.06
# dtype: float64

# %%
ls_drop = ["gross", "genre_4", "genre_3", "title_year"]

# %%
ls_cont = [x for x in ls_cont if x not in ls_drop]
ls_disc = [x for x in ls_disc if x not in ls_drop]

# %%
df = df.dropna(subset = ls_cont+ls_disc).reset_index(drop = True)

# %%
df.shape
# Out:
# (4168, 16)

# %%
df.sample(10)
# Out:
#                              movie_title  \
# 3882                       Dear Frankie
# 1104                     Reindeer Games
# 2813                               Jaws
# 1554             The Work and the Glory
# 617           The Sorcerer's Apprentice
# 751                          Ride Along
# 1095                     Mercury Rising
# 3379             The Legend of Hercules
# 4108     Dead Like Me: Life After Death
# 267   Harold & Kumar Go to White Castle
#
#                                         movie_imdb_link  color   genre_4  \
# 3882  http://www.imdb.com/title/tt0377752/?ref_=fn_t...  Color       NaN
# 1104  http://www.imdb.com/title/tt0184858/?ref_=fn_t...  Color     Drama
# 2813  http://www.imdb.com/title/tt0073195/?ref_=fn_t...  Color       NaN
# 1554  http://www.imdb.com/title/tt0410454/?ref_=fn_t...  Color       NaN
# 617   http://www.imdb.com/title/tt0963966/?ref_=fn_t...  Color   Fantasy
# 751   http://www.imdb.com/title/tt1408253/?ref_=fn_t...  Color   Romance
# 1095  http://www.imdb.com/title/tt0120749/?ref_=fn_t...  Color  Thriller
# 3379  http://www.imdb.com/title/tt1043726/?ref_=fn_t...  Color       NaN
# 4108  http://www.imdb.com/title/tt1079444/?ref_=fn_t...  Color       NaN
# 267   http://www.imdb.com/title/tt0366551/?ref_=fn_t...  Color       NaN
#
#       duration          gross    genre_1    genre_2   genre_3  \
# 3882    105.00   1,340,891.00      Drama    Romance       NaN
# 1104    124.00            NaN     Action  Adventure     Crime
# 2813    130.00 260,000,000.00  Adventure      Drama  Thriller
# 1554    118.00            NaN      Drama    Romance       NaN
# 617     109.00  63,143,812.00     Action  Adventure    Family
# 751      99.00 134,141,530.00     Action     Comedy     Crime
# 1095    111.00            NaN     Action      Crime     Drama
# 3379     99.00            NaN     Action  Adventure   Fantasy
# 4108     87.00            NaN     Comedy      Drama   Fantasy
# 267      88.00            NaN  Adventure     Comedy       NaN
#
#       num_voted_users facenumber_in_poster language country content_rating  \
# 3882        18,940.00                    0  English      UK          PG-13
# 1104        31,113.00                    0  English     USA              R
# 2813       412,454.00                    0  English     USA             PG
# 1554           833.00                    1  English     USA             PG
# 617        124,185.00                    0  English     USA             PG
# 751         75,903.00                    1  English     USA          PG-13
# 1095        54,316.00                    1  English     USA              R
# 3379        44,891.00                    0  English     USA          PG-13
# 4108        10,734.00                    1  English     USA              R
# 267        155,262.00                    2  English     USA              R
#
#       title_year  imdb_score
# 3882    2,004.00        7.80
# 1104    2,000.00        5.70
# 2813    1,975.00        8.00
# 1554    2,004.00        6.90
# 617     2,010.00        6.10
# 751     2,014.00        6.20
# 1095    1,998.00        6.10
# 3379    2,014.00        4.20
# 4108    2,009.00        6.10
# 267     2,004.00        7.10

# %%
df["content_rating"] = df["content_rating"].map(normalize_content)

# %% [markdown]
# ## Modelado

# %% [markdown]
# ### Preparación de sets

# %%
X = df.drop(columns=ls_disc)[ls_cont].join(pd.get_dummies(df[ls_disc]))
y = df[target]

# %%
X.shape
# Out:
# (4168, 134)

# %%
kb = SelectKBest(k = 5, score_func=f_regression)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,random_state=0)

# %%
kb.fit(X_train, y_train)
# Out:
# /Users/jesusarredondo/Documents/Diplomado/Modulo2/mod2/lib/python3.9/site-packages/sklearn/feature_selection/_univariate_selection.py:289: RuntimeWarning:
#
# invalid value encountered in true_divide
# SelectKBest(k=5, score_func=<function f_regression at 0x7f886ce1f820>)

# %%
ls_best = [x for x, y in zip(X.columns, kb.get_support()) if y]

# %%
X.columns
# Out:
# Index(['duration', 'num_voted_users', 'facenumber_in_poster',
#        'color_ Black and White', 'color_Color', 'genre_1_Action',
#        'genre_1_Adventure', 'genre_1_Animation', 'genre_1_Biography',
#        'genre_1_Comedy',
#        ...
#        'country_Taiwan', 'country_Thailand', 'country_UK', 'country_USA',
#        'country_West Germany', 'content_rating_Approved',
#        'content_rating_Not Rated', 'content_rating_Parental Guiadance',
#        'content_rating_Publico General', 'content_rating_Restricted'],
#       dtype='object', length=134)

# %%
ls_best
# Out:
# ['duration',
#  'num_voted_users',
#  'color_Color',
#  'genre_1_Biography',
#  'genre_2_Drama']

# %%
X_train=X_train[ls_best]

# %%
X_test=X_test[ls_best]

# %% [markdown]
# ### Modelos

# %%
linreg = LinearRegression()

# %%
linreg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
linreg.predict(X_test)
# Out:
# array([7.43535462, 8.68256888, 6.67504051, ..., 6.14048016, 7.41992002,
#        7.42246765])

# %%
r2_score(y_pred=linreg.predict(X_test), y_true=y_test)
# Out:
# 0.25650264122103505

# %%
linreg.coef_
# Out:
# array([ 5.15622176e-03,  3.03760668e-06, -6.96127397e-01,  5.06622313e-01,
#         3.22358928e-01])

# %%
linreg.coef_.round(3)
# Out:
# array([ 0.005,  0.   , -0.696,  0.507,  0.322])

# %%
mean_absolute_error(y_pred=linreg.predict(X_test), y_true=y_test)
# Out:
# 0.7079692829199522

# %%
yc_train = (y_train > y_train.mean())*1
yc_test = (y_test > y_train.mean())*1

# %%
y_train
# Out:
# 2590   6.40
# 519    6.50
# 1721   6.70
# 1861   6.10
# 936    6.90
#        ...
# 1033   4.10
# 3264   7.90
# 1653   6.70
# 2607   6.90
# 2732   7.10
# Name: imdb_score, Length: 3126, dtype: float64

# %%
yc_train
# Out:
# 2590    0
# 519     1
# 1721    1
# 1861    0
# 936     1
#        ..
# 1033    0
# 3264    1
# 1653    1
# 2607    1
# 2732    1
# Name: imdb_score, Length: 3126, dtype: int64

# %%
yc_train.value_counts(1)
# Out:
# 1   0.56
# 0   0.44
# Name: imdb_score, dtype: float64

# %%
yc_test.value_counts(1)
# Out:
# 1   0.51
# 0   0.49
# Name: imdb_score, dtype: float64

# %%
logreg = LogisticRegression()

# %%
logreg.fit(X_train, yc_train)
# Out:
# LogisticRegression()

# %%
roc_auc_score(y_score=logreg.predict_proba(X_train)[:,1],y_true=yc_train )
# Out:
# 0.6838008575077541

# %%
roc_auc_score(y_score=logreg.predict_proba(X_test)[:,1],y_true=yc_test )
# Out:
# 0.6653099596305923

# %%
X_train[ls_best]
# Out:
#       duration  num_voted_users  color_Color  genre_1_Biography  genre_2_Drama
# 2590    107.00        38,191.00            1                  0              0
# 519     114.00        87,950.00            1                  0              1
# 1721     89.00        29,843.00            1                  0              0
# 1861     90.00        86,890.00            1                  0              0
# 936     130.00        29,932.00            1                  0              0
# ...        ...              ...          ...                ...            ...
# 1033     95.00         4,875.00            1                  0              0
# 3264    102.00       279,093.00            1                  0              0
# 1653    106.00       271,592.00            1                  0              0
# 2607     81.00        52,055.00            1                  0              0
# 2732    125.00       143,525.00            1                  0              1
#
# [3126 rows x 5 columns]
