# %%
import pandas as pd
import os

pd.set_option('display.max_columns', 500)

data_path = os.getcwd()[:-len('notebooks')] + 'Data/'
db_beijing_path = data_path + 'Beijing_winter_Olympic_Games/'

# %%
os.listdir(db_beijing_path)
# Out:
# ['hockey_results.csv',
#  'curling_results.csv',
#  'athletes.csv',
#  'technical_officials.csv',
#  'medals_total.csv',
#  'coaches.csv',
#  'entries_discipline.csv',
#  'hockey_players_stats.csv',
#  'medals.csv',
#  'events.csv']

# %%
df_athletes = pd.read_csv(db_beijing_path+'athletes.csv')
df_technical_officials = pd.read_csv(db_beijing_path+'technical_officials.csv')
df_coaches = pd.read_csv(db_beijing_path+'coaches.csv')
df_medals = pd.read_csv(db_beijing_path + 'medals.csv')

# %%
df_athletes.head(3)
# Out:
#              name  short_name gender  birth_date    birth_place birth_country  \
# 0  AAGAARD Mikkel   AAGAARD M   Male  1995-10-18  FREDERIKSHAVN       Denmark
# 1     AALTO Antti     AALTO A   Male  1995-04-02          KITEE       Finland
# 2   AALTONEN Miro  AALTONEN M   Male  1993-06-07        JOENSUU       Finland
#
#    country country_code   discipline discipline_code residence_place  \
# 0  Denmark          DEN   Ice Hockey             IHO    ORNSKOLDSVIK
# 1  Finland          FIN  Ski Jumping             SJP          KUOPIO
# 2  Finland          FIN   Ice Hockey             IHO         PODOLSK
#
#     residence_country  height_m/ft  \
# 0              Sweden   1.84/6'0''
# 1             Finland          NaN
# 2  Russian Federation  1.80/5'10''
#
#                                                  url
# 0  ../../../en/results/ice-hockey/athlete-profile...
# 1  ../../../en/results/ski-jumping/athlete-profil...
# 2  ../../../en/results/ice-hockey/athlete-profile...

# %%
df_technical_officials.head(3)
# Out:
#              name  gender  birth_date             country      discipline  \
# 0     ABELE Agita  Female  1964-02-19              Latvia  Figure Skating
# 1    AHN Na Young  Female  1969-08-15   Republic of Korea  Figure Skating
# 2  ANDREEVA Julia  Female  1980-03-24  Russian Federation  Figure Skating
#
#   function                                                url
# 0    Judge  ../../../en/results/figure-skating/athlete-pro...
# 1    Judge  ../../../en/results/figure-skating/athlete-pro...
# 2    Judge  ../../../en/results/figure-skating/athlete-pro...

# %%
df_coaches.head(3)
# Out:
#             name gender  birth_date                   country discipline  \
# 0    BARES Jakub   Male  1988-03-20            Czech Republic    Curling
# 1  BEIGHTON Sean   Male  1988-11-22  United States of America    Curling
# 2  BEIGHTON Sean   Male  1988-11-22  United States of America    Curling
#
#   function          event                                                url
# 0    Coach  Mixed Doubles  ../../../en/results/curling/athlete-profile-n1...
# 1    Coach            Men  ../../../en/results/curling/athlete-profile-n1...
# 2    Coach  Mixed Doubles  ../../../en/results/curling/athlete-profile-n1...

# %%
df_medals.head(3)
# Out:
#   medal_type  medal_code             medal_date athlete_short_name  \
# 0       Gold           1  2022-02-05 00:00:00.0          ECKHOFF T
# 1       Gold           1  2022-02-05 00:00:00.0      ROEISELAND MO
# 2       Gold           1  2022-02-05 00:00:00.0              BOE T
#
#              athlete_name athlete_sex  \
# 0           ECKHOFF Tiril           X
# 1  ROEISELAND Marte Olsbu           X
# 2              BOE Tarjei           X
#
#                                         athlete_link                    event  \
# 0  ../../../en/results/biathlon/athlete-profile-n...  Mixed Relay 4x6km (W+M)
# 1  ../../../en/results/biathlon/athlete-profile-n...  Mixed Relay 4x6km (W+M)
# 2  ../../../en/results/biathlon/athlete-profile-n...  Mixed Relay 4x6km (W+M)
#
#   country country_code discipline discipline_code
# 0  Norway          NOR   Biathlon             BTH
# 1  Norway          NOR   Biathlon             BTH
# 2  Norway          NOR   Biathlon             BTH

# %%
df_medals['athlete_link'][0]
# Out:
# '../../../en/results/biathlon/athlete-profile-n1031947-tiril-eckhoff.htm'

# %%
df_athletes[df_athletes['url']=='../../../en/results/biathlon/athlete-profile-n1031947-tiril-eckhoff.htm']
# Out:
#               name short_name  gender  birth_date birth_place birth_country  \
# 561  ECKHOFF Tiril  ECKHOFF T  Female  1990-05-21      BAERUM        Norway
#
#     country country_code discipline discipline_code residence_place  \
# 561  Norway          NOR   Biathlon             BTH            OSLO
#
#     residence_country height_m/ft  \
# 561            Norway         NaN
#
#                                                    url
# 561  ../../../en/results/biathlon/athlete-profile-n...

# %%
df_athletes['country'].value_counts()
# Out:
# United States of America      225
# ROC                           217
# Canada                        215
# People's Republic of China    182
# Switzerland                   169
#                              ...
# American Samoa                  1
# Saudi Arabia                    1
# Eritrea                         1
# Morocco                         1
# Albania                         1
# Name: country, Length: 91, dtype: int64

# %%
paises = list(set(df_athletes['country']))
paises
# Out:
# ['Bosnia and Herzegovina',
#  'India',
#  'Japan',
#  'Peru',
#  'Israel',
#  'Bulgaria',
#  'Brazil',
#  'Latvia',
#  'Thailand',
#  'Austria',
#  'Poland',
#  'Andorra',
#  'Canada',
#  'Italy',
#  'Ireland',
#  'Kosovo',
#  'Argentina',
#  'Nigeria',
#  'Belarus',
#  'Colombia',
#  'Serbia',
#  'Armenia',
#  'Turkey',
#  'Sweden',
#  'North Macedonia',
#  'Iceland',
#  'Eritrea',
#  'Chinese Taipei',
#  'Ecuador',
#  'Finland',
#  'Uzbekistan',
#  'Croatia',
#  'Malta',
#  'Islamic Republic of Iran',
#  'ROC',
#  'Spain',
#  'Pakistan',
#  'Germany',
#  'Republic of Moldova',
#  'Georgia',
#  'Timor-Leste',
#  'Kyrgyzstan',
#  'Philippines',
#  'Estonia',
#  'France',
#  'Bolivia',
#  'Trinidad and Tobago',
#  'Luxembourg',
#  'Belgium',
#  'Azerbaijan',
#  'Greece',
#  'San Marino',
#  'Slovenia',
#  "People's Republic of China",
#  'Monaco',
#  'Jamaica',
#  'Hong Kong, China',
#  'Denmark',
#  'LBN',
#  'Virgin Islands, US',
#  'American Samoa',
#  'Hungary',
#  'Ghana',
# ...

# %%
paises_medallas = list(set(df_medals['country']))
paises_medallas
# Out:
# ['Estonia',
#  'France',
#  'Norway',
#  'New Zealand',
#  'Ukraine',
#  'Japan',
#  'Slovakia',
#  'Belgium',
#  'Latvia',
#  'Czech Republic',
#  'Great Britain',
#  'Netherlands',
#  'Finland',
#  'Austria',
#  'Slovenia',
#  "People's Republic of China",
#  'Poland',
#  'United States of America',
#  'Canada',
#  'Italy',
#  'Australia',
#  'ROC',
#  'Spain',
#  'Switzerland',
#  'Germany',
#  'Belarus',
#  'Hungary',
#  'Republic of Korea',
#  'Sweden']

# %%
paises.sort()

# %%
paises_medallas.sort()

# %%
paises == paises_medallas
# Out:
# False

# %%
paises_medallas
# Out:
# ['Australia',
#  'Austria',
#  'Belarus',
#  'Belgium',
#  'Canada',
#  'Czech Republic',
#  'Estonia',
#  'Finland',
#  'France',
#  'Germany',
#  'Great Britain',
#  'Hungary',
#  'Italy',
#  'Japan',
#  'Latvia',
#  'Netherlands',
#  'New Zealand',
#  'Norway',
#  "People's Republic of China",
#  'Poland',
#  'ROC',
#  'Republic of Korea',
#  'Slovakia',
#  'Slovenia',
#  'Spain',
#  'Sweden',
#  'Switzerland',
#  'Ukraine',
#  'United States of America']

# %%
paises
# Out:
# ['Albania',
#  'American Samoa',
#  'Andorra',
#  'Argentina',
#  'Armenia',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Belarus',
#  'Belgium',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Brazil',
#  'Bulgaria',
#  'Canada',
#  'Chile',
#  'Chinese Taipei',
#  'Colombia',
#  'Croatia',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'Ecuador',
#  'Eritrea',
#  'Estonia',
#  'Finland',
#  'France',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Great Britain',
#  'Greece',
#  'Haiti',
#  'Hong Kong, China',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Ireland',
#  'Islamic Republic of Iran',
#  'Israel',
#  'Italy',
#  'Jamaica',
#  'Japan',
#  'Kazakhstan',
#  'Kosovo',
#  'Kyrgyzstan',
#  'LBN',
#  'Latvia',
#  'Liechtenstein',
#  'Lithuania',
#  'Luxembourg',
#  'Madagascar',
#  'Malaysia',
#  'Malta',
#  'Mexico',
#  'Monaco',
#  'Mongolia',
#  'Montenegro',
#  'Morocco',
#  'Netherlands',
#  'New Zealand',
#  'Nigeria',
#  'North Macedonia',
#  'Norway',
#  'Pakistan',
# ...

# %%
paises_technical = list(set(df_technical_officials['country']))
paises_coaches = list(set(df_coaches['country']))

# %%
paises_totales = list(set(paises + paises_medallas+ paises_technical+paises_coaches))

# %%
paises_totales.sort()

# %%
paises_totales
# Out:
# ['Albania',
#  'American Samoa',
#  'Andorra',
#  'Argentina',
#  'Armenia',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Belarus',
#  'Belgium',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Brazil',
#  'Bulgaria',
#  'Canada',
#  'Chile',
#  'Chinese Taipei',
#  'Colombia',
#  'Croatia',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'Ecuador',
#  'Eritrea',
#  'Estonia',
#  'Finland',
#  'France',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Great Britain',
#  'Greece',
#  'Haiti',
#  'Hong Kong, China',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Ireland',
#  'Islamic Republic of Iran',
#  'Israel',
#  'Italy',
#  'Jamaica',
#  'Japan',
#  'Kazakhstan',
#  'Kosovo',
#  'Kyrgyzstan',
#  'LBN',
#  'Latvia',
#  'Liechtenstein',
#  'Lithuania',
#  'Luxembourg',
#  'Madagascar',
#  'Malaysia',
#  'Malta',
#  'Mexico',
#  'Monaco',
#  'Mongolia',
#  'Montenegro',
#  'Morocco',
#  'Netherlands',
#  'New Zealand',
#  'Nigeria',
#  'North Macedonia',
#  'Norway',
#  'Pakistan',
# ...

# %%
# Para atletas hombres y mujeres

df_athletes
# Out:
#                    name    short_name  gender  birth_date  \
# 0        AAGAARD Mikkel     AAGAARD M    Male  1995-10-18
# 1           AALTO Antti       AALTO A    Male  1995-04-02
# 2         AALTONEN Miro    AALTONEN M    Male  1993-06-07
# 3     ABDELKADER Justin  ABDELKADER J    Male  1987-02-25
# 4            ABDI Fayik        ABDI F    Male  1997-10-07
# ...                 ...           ...     ...         ...
# 2892       ZUREK Damian       ZUREK D    Male  1999-09-17
# 2893      ZUYEVA Maryna      ZUYEVA M  Female  1992-03-20
# 2894        ZUZIN Peter       ZUZIN P    Male  1990-09-04
# 2895     ZVEJNIEKS Miks   ZVEJNIEKS M    Male  1995-03-08
# 2896         ZYLA Piotr        ZYLA P    Male  1987-01-16
#
#               birth_place             birth_country                   country  \
# 0           FREDERIKSHAVN                   Denmark                   Denmark
# 1                   KITEE                   Finland                   Finland
# ...

# %%
df_atletas_sub = df_athletes[['name','gender','birth_date','country','url']]

# %%
df_atletas_sub.head(1)
# Out:
#              name gender  birth_date  country  \
# 0  AAGAARD Mikkel   Male  1995-10-18  Denmark
#
#                                                  url
# 0  ../../../en/results/ice-hockey/athlete-profile...

# %%
df_atletas_sub[['country','gender']].groupby(['gender']).count()
# Out:
#         country
# gender
# F             5
# Female     1290
# M             7
# Male       1595

# %%
for renglon in range(len(df_athletes)):
    if df_athletes["gender"][renglon]=='Female':
        df_athletes["gender"][renglon]="F"
    elif df_athletes["gender"][renglon]=='Male':
        df_athletes["gender"][renglon]="M"

# %%
df_atletas_sub = df_athletes[['name','gender','birth_date','country','url']]

# %%
df_atletas_sub[['country','gender','name']].groupby(['country','gender']).count()
# Out:
#                                  name
# country                  gender
# Albania                  M          1
# American Samoa           M          1
# Andorra                  F          3
#                          M          2
# Argentina                F          4
# ...                               ...
# Ukraine                  M         24
# United States of America F        108
#                          M        117
# Uzbekistan               M          1
# Virgin Islands, US       F          1
#
# [160 rows x 1 columns]

# %%
generos_atletas = df_atletas_sub[['country','gender','name']].pivot_table(index = 'country',columns = 'gender', aggfunc = 'count', values = 'name', fill_value = 0)

# %%
generos_atletas
# Out:
# gender                      F    M
# country
# Albania                     0    1
# American Samoa              0    1
# Andorra                     3    2
# Argentina                   4    2
# Armenia                     3    3
# ...                       ...  ...
# Turkey                      3    4
# Ukraine                    22   24
# United States of America  108  117
# Uzbekistan                  0    1
# Virgin Islands, US          1    0
#
# [91 rows x 2 columns]

# %%
generos_atletas["Totales"]=generos_atletas["F"]+generos_atletas["M"]
generos_atletas
# Out:
# gender                      F    M  Totales
# country
# Albania                     0    1        1
# American Samoa              0    1        1
# Andorra                     3    2        5
# Argentina                   4    2        6
# Armenia                     3    3        6
# ...                       ...  ...      ...
# Turkey                      3    4        7
# Ukraine                    22   24       46
# United States of America  108  117      225
# Uzbekistan                  0    1        1
# Virgin Islands, US          1    0        1
#
# [91 rows x 3 columns]

# %%
len(df_athletes)
# Out:
# 2897

# %%
sum(list(generos_atletas["Totales"]))
# Out:
# 2897

# %%
#Coaches 

df_coaches.groupby(['gender']).count()
# Out:
#         name  birth_date  country  discipline  function  event  url
# gender
# Female     7           7        7           7         7      3    7
# Male      70          70       70          70        70     51   70

# %%
df_coaches.head(1)
# Out:
#           name gender  birth_date         country discipline function  \
# 0  BARES Jakub   Male  1988-03-20  Czech Republic    Curling    Coach
#
#            event                                                url
# 0  Mixed Doubles  ../../../en/results/curling/athlete-profile-n1...

# %%
df_coaches_sub = df_coaches[['name','gender','country','url']]

# %%
generos_coaches = df_coaches_sub[['country','gender','name']].pivot_table(index = 'country',columns = 'gender', aggfunc = 'count', values = 'name', fill_value = 0)

# %%
generos_coaches
# Out:
# gender                      Female  Male
# country
# Australia                        0     1
# Canada                           1     6
# Czech Republic                   0     3
# Denmark                          3     6
# Finland                          1     2
# Germany                          0     2
# Great Britain                    0     4
# Italy                            0     3
# Japan                            0     3
# Latvia                           0     1
# Norway                           0     4
# People's Republic of China       0     7
# ROC                              0     4
# Republic of Korea                0     1
# Slovakia                         0     1
# Sweden                           1     7
# Switzerland                      0    11
# United States of America         1     4

# %%
generos_coaches["Totales"]=generos_coaches["Female"]+generos_coaches["Male"]

# %%
generos_coaches
# Out:
# gender                      Female  Male  Totales
# country
# Australia                        0     1        1
# Canada                           1     6        7
# Czech Republic                   0     3        3
# Denmark                          3     6        9
# Finland                          1     2        3
# Germany                          0     2        2
# Great Britain                    0     4        4
# Italy                            0     3        3
# Japan                            0     3        3
# Latvia                           0     1        1
# Norway                           0     4        4
# People's Republic of China       0     7        7
# ROC                              0     4        4
# Republic of Korea                0     1        1
# Slovakia                         0     1        1
# Sweden                           1     7        8
# Switzerland                      0    11       11
# United States of America         1     4        5

# %%
# Oficiales 

df_technical_officials.groupby("gender").count()
# Out:
#         name  birth_date  country  discipline  function  url
# gender
# Female    40          40       40          40        40   40
# Male      16          16       16          16        16   16

# %%
df_technical_officials.columns
# Out:
# Index(['name', 'gender', 'birth_date', 'country', 'discipline', 'function',
#        'url'],
#       dtype='object')

# %%
df_tecnicos_sub = df_technical_officials[['name','gender','country','url']]

# %%
generos_tecnicos = df_tecnicos_sub[['country','gender','name']].pivot_table(index = 'country',columns = 'gender', aggfunc = 'count', values = 'name', fill_value = 0)

# %%
generos_tecnicos
# Out:
# gender                      Female  Male
# country
# Austria                          1     1
# Belarus                          1     0
# Canada                           4     0
# Czech Republic                   1     1
# Estonia                          2     0
# Finland                          2     1
# France                           0     2
# Germany                          2     1
# Great Britain                    1     1
# Hungary                          1     0
# Israel                           1     1
# Italy                            2     2
# Japan                            3     1
# Latvia                           1     0
# Lithuania                        1     0
# Mexico                           1     0
# Netherlands                      1     1
# People's Republic of China       3     1
# Poland                           1     0
# Republic of Korea                2     0
# Russian Federation               3     1
# Spain                            1     1
# ...

# %%
generos_tecnicos["Totales"]= generos_tecnicos["Female"]+generos_tecnicos["Male"]

# %%
generos_tecnicos
# Out:
# gender                      Female  Male  Totales
# country
# Austria                          1     1        2
# Belarus                          1     0        1
# Canada                           4     0        4
# Czech Republic                   1     1        2
# Estonia                          2     0        2
# Finland                          2     1        3
# France                           0     2        2
# Germany                          2     1        3
# Great Britain                    1     1        2
# Hungary                          1     0        1
# Israel                           1     1        2
# Italy                            2     2        4
# Japan                            3     1        4
# Latvia                           1     0        1
# Lithuania                        1     0        1
# Mexico                           1     0        1
# Netherlands                      1     1        2
# People's Republic of China       3     1        4
# ...

# %%
# Medallas
df_medals
# Out:
#     medal_type  medal_code             medal_date athlete_short_name  \
# 0         Gold           1  2022-02-05 00:00:00.0          ECKHOFF T
# 1         Gold           1  2022-02-05 00:00:00.0      ROEISELAND MO
# 2         Gold           1  2022-02-05 00:00:00.0              BOE T
# 3         Gold           1  2022-02-05 00:00:00.0             BOE JT
# 4       Silver           2  2022-02-05 00:00:00.0  CHEVALIER-BOUCHET
# ..         ...         ...                    ...                ...
# 689     Silver           2  2022-02-20 00:00:00.0         CHIBISOV A
# 690     Silver           2  2022-02-20 00:00:00.0     SHARIPZYANOV D
# 691     Silver           2  2022-02-20 00:00:00.0         NIKISHIN A
# 692     Silver           2  2022-02-20 00:00:00.0          TELEGIN S
# 693     Silver           2  2022-02-20 00:00:00.0         TKACHYOV V
#
#                 athlete_name athlete_sex  \
# 0              ECKHOFF Tiril           X
# 1     ROEISELAND Marte Olsbu           X
# ...

# %%
df_medallas_sub = df_medals[["medal_code","medal_date","athlete_link","country","athlete_name"]]

# %%
conteo_medallas = df_medallas_sub[['country','medal_code','athlete_name']].pivot_table(index = 'country',columns = 'medal_code', aggfunc = 'count', values = 'athlete_name', fill_value = 0)

# %%
conteo_medallas
# Out:
# medal_code                   1   2   3
# country
# Australia                    1   2   1
# Austria                     15  10   5
# Belarus                      0   2   0
# Belgium                      1   0   1
# Canada                      32   8  27
# Czech Republic               1   0   1
# Estonia                      0   0   1
# Finland                     26   3  26
# France                       6  13   5
# Germany                     22  26  12
# Great Britain                5   5   0
# Hungary                      1   0   6
# Italy                        3  13  11
# Japan                        3  12  19
# Latvia                       0   0   4
# Netherlands                 11   5   7
# New Zealand                  2   1   0
# Norway                      28  12  18
# People's Republic of China  14   6   6
# Poland                       0   0   1
# ROC                         17  46  23
# Republic of Korea            2  12   2
# Slovakia                     1   0  25
# ...

# %%
conteo_medallas["Totales"]=conteo_medallas[1]+conteo_medallas[2]+conteo_medallas[3]

# %%
conteo_medallas
# Out:
# medal_code                   1   2   3  Totales
# country
# Australia                    1   2   1        4
# Austria                     15  10   5       30
# Belarus                      0   2   0        2
# Belgium                      1   0   1        2
# Canada                      32   8  27       67
# Czech Republic               1   0   1        2
# Estonia                      0   0   1        1
# Finland                     26   3  26       55
# France                       6  13   5       24
# Germany                     22  26  12       60
# Great Britain                5   5   0       10
# Hungary                      1   0   6        7
# Italy                        3  13  11       27
# Japan                        3  12  19       34
# Latvia                       0   0   4        4
# Netherlands                 11   5   7       23
# New Zealand                  2   1   0        3
# Norway                      28  12  18       58
# ...

# %% [markdown]
# # Medallas por genero

# %%
df_medallas_sub
# Out:
#      medal_code             medal_date  \
# 0             1  2022-02-05 00:00:00.0
# 1             1  2022-02-05 00:00:00.0
# 2             1  2022-02-05 00:00:00.0
# 3             1  2022-02-05 00:00:00.0
# 4             2  2022-02-05 00:00:00.0
# ..          ...                    ...
# 689           2  2022-02-20 00:00:00.0
# 690           2  2022-02-20 00:00:00.0
# 691           2  2022-02-20 00:00:00.0
# 692           2  2022-02-20 00:00:00.0
# 693           2  2022-02-20 00:00:00.0
#
#                                           athlete_link country  \
# 0    ../../../en/results/biathlon/athlete-profile-n...  Norway
# 1    ../../../en/results/biathlon/athlete-profile-n...  Norway
# 2    ../../../en/results/biathlon/athlete-profile-n...  Norway
# 3    ../../../en/results/biathlon/athlete-profile-n...  Norway
# 4    ../../../en/results/biathlon/athlete-profile-n...  France
# ..                                                 ...     ...
# ...

# %%
df_atletas_sub
# Out:
#                    name gender  birth_date                   country  \
# 0        AAGAARD Mikkel      M  1995-10-18                   Denmark
# 1           AALTO Antti      M  1995-04-02                   Finland
# 2         AALTONEN Miro      M  1993-06-07                   Finland
# 3     ABDELKADER Justin      M  1987-02-25  United States of America
# 4            ABDI Fayik      M  1997-10-07              Saudi Arabia
# ...                 ...    ...         ...                       ...
# 2892       ZUREK Damian      M  1999-09-17                    Poland
# 2893      ZUYEVA Maryna      F  1992-03-20                   Belarus
# 2894        ZUZIN Peter      M  1990-09-04                  Slovakia
# 2895     ZVEJNIEKS Miks      M  1995-03-08                    Latvia
# 2896         ZYLA Piotr      M  1987-01-16                    Poland
#
#                                                     url
# 0     ../../../en/results/ice-hockey/athlete-profile...
# ...

# %%
df_medalles = df_atletas_sub.merge(df_medallas_sub,left_on = 'url', right_on = 'athlete_link',suffixes = ("_atletas","_medallas"), how = 'inner')

# %%
df_medalles
# Out:
#                     name gender  birth_date             country_atletas  \
# 0          AALTONEN Miro      M  1993-06-07                     Finland
# 1    ABRAMENKO Oleksandr      M  1988-05-04                     Ukraine
# 2            AICHER Emma      F  2003-11-13                     Germany
# 3       ALDOSHKIN Daniil      M  2001-06-19                         ROC
# 4      ALTHAUS Katharina      F  1996-05-23                     Germany
# ..                   ...    ...         ...                         ...
# 689         ZHANG Yuting      F  1999-08-04  People's Republic of China
# 690         ZHANG Yuting      F  1999-08-04  People's Republic of China
# 691         ZHOU Vincent      M  2000-10-25    United States of America
# 692      ZUMWINKLE Grace      F  1999-04-23    United States of America
# 693          ZUZIN Peter      M  1990-09-04                    Slovakia
#
#                                                    url  medal_code  \
# ...

# %%
df_medalles_sub = df_medalles[["gender","birth_date","country_atletas","medal_code","name"]]

# %%
df_medalles_sub
# Out:
#     gender  birth_date             country_atletas  medal_code  \
# 0        M  1993-06-07                     Finland           1
# 1        M  1988-05-04                     Ukraine           2
# 2        F  2003-11-13                     Germany           2
# 3        M  2001-06-19                         ROC           2
# 4        F  1996-05-23                     Germany           2
# ..     ...         ...                         ...         ...
# 689      F  1999-08-04  People's Republic of China           1
# 690      F  1999-08-04  People's Republic of China           3
# 691      M  2000-10-25    United States of America           2
# 692      F  1999-04-23    United States of America           2
# 693      M  1990-09-04                    Slovakia           3
#
#                     name
# 0          AALTONEN Miro
# 1    ABRAMENKO Oleksandr
# 2            AICHER Emma
# 3       ALDOSHKIN Daniil
# 4      ALTHAUS Katharina
# ..                   ...
# ...

# %%
df_medallas_genero = df_medalles_sub[['country_atletas','medal_code','gender']].pivot_table(index = 'country_atletas',columns = 'medal_code', aggfunc = 'count', values = 'gender', fill_value = 0)

# %%
df_medallas_genero
# Out:
# medal_code                   1   2   3
# country_atletas
# Australia                    1   2   1
# Austria                     15  10   5
# Belarus                      0   2   0
# Belgium                      1   0   1
# Canada                      32   8  27
# Czech Republic               1   0   1
# Estonia                      0   0   1
# Finland                     26   3  26
# France                       6  13   5
# Germany                     22  26  12
# Great Britain                5   5   0
# Hungary                      1   0   6
# Italy                        3  13  11
# Japan                        3  12  19
# Latvia                       0   0   4
# Netherlands                 11   5   7
# New Zealand                  2   1   0
# Norway                      28  12  18
# People's Republic of China  14   6   6
# Poland                       0   0   1
# ROC                         17  46  23
# Republic of Korea            2  12   2
# ...

# %%
df_medalles_sub[['country_atletas','medal_code','gender']].groupby(["country_atletas","gender"]).agg(["count"])
# Out:
#                                   medal_code
#                                        count
# country_atletas            gender
# Australia                  F               3
#                            M               1
# Austria                    F               9
#                            M              21
# Belarus                    F               1
#                            M               1
# Belgium                    F               1
#                            M               1
# Canada                     F              39
#                            M              28
# Czech Republic             F               2
# Estonia                    F               1
# Finland                    F              26
#                            M              29
# France                     F               7
#                            M              17
# Germany                    F              23
#                            M              37
# ...

# %%
df_medalles_sub[['country_atletas','medal_code','gender']].pivot_table(index = 'country_atletas',columns = 'medal_code', aggfunc = 'count', values = 'gender', fill_value = 0)

# %%
df_medalles_sub.head(1)
# Out:
#   gender  birth_date country_atletas  medal_code           name
# 0      M  1993-06-07         Finland           1  AALTONEN Miro

# %%
df_medallas_hombre = df_medalles_sub.loc[df_medalles_sub["gender"]=="M"].pivot_table(index = 'country_atletas',columns = 'medal_code', aggfunc = 'count', values = 'gender', fill_value = 0)

# %%
df_medallas_mujer = df_medalles_sub.loc[df_medalles_sub["gender"]=="F"].pivot_table(index = 'country_atletas',columns = 'medal_code', aggfunc = 'count', values = 'gender', fill_value = 0)

# %%
# Conclusion

df_final = pd.DataFrame(columns = ["Total de atletas","Total de Atletas hombres", "Total de Atletas mujeres","Male coaches","Female coaches","Male Officials","Female Officials","Male Total Medals","Femal Total Medals","Male Gold","Male Silver","Male Bronce","Female Gold","Female Silver","Female Brone"],\
                       index = paises_totales)

# %%
df_final
# Out:
#                          Total de atletas Total de Atletas hombres  \
# Albania                               NaN                      NaN
# American Samoa                        NaN                      NaN
# Andorra                               NaN                      NaN
# Argentina                             NaN                      NaN
# Armenia                               NaN                      NaN
# ...                                   ...                      ...
# Turkey                                NaN                      NaN
# Ukraine                               NaN                      NaN
# United States of America              NaN                      NaN
# Uzbekistan                            NaN                      NaN
# Virgin Islands, US                    NaN                      NaN
#
#                          Total de Atletas mujeres Male coaches Female coaches  \
# Albania                                       NaN          NaN            NaN
# ...

# %%
generos_atletas
# Out:
# gender                      F    M  Totales
# country
# Albania                     0    1        1
# American Samoa              0    1        1
# Andorra                     3    2        5
# Argentina                   4    2        6
# Armenia                     3    3        6
# ...                       ...  ...      ...
# Turkey                      3    4        7
# Ukraine                    22   24       46
# United States of America  108  117      225
# Uzbekistan                  0    1        1
# Virgin Islands, US          1    0        1
#
# [91 rows x 3 columns]

# %%
generos_atletas.index
# Out:
# Index(['Albania', 'American Samoa', 'Andorra', 'Argentina', 'Armenia',
#        'Australia', 'Austria', 'Azerbaijan', 'Belarus', 'Belgium', 'Bolivia',
#        'Bosnia and Herzegovina', 'Brazil', 'Bulgaria', 'Canada', 'Chile',
#        'Chinese Taipei', 'Colombia', 'Croatia', 'Cyprus', 'Czech Republic',
#        'Denmark', 'Ecuador', 'Eritrea', 'Estonia', 'Finland', 'France',
#        'Georgia', 'Germany', 'Ghana', 'Great Britain', 'Greece', 'Haiti',
#        'Hong Kong, China', 'Hungary', 'Iceland', 'India', 'Ireland',
#        'Islamic Republic of Iran', 'Israel', 'Italy', 'Jamaica', 'Japan',
#        'Kazakhstan', 'Kosovo', 'Kyrgyzstan', 'LBN', 'Latvia', 'Liechtenstein',
#        'Lithuania', 'Luxembourg', 'Madagascar', 'Malaysia', 'Malta', 'Mexico',
#        'Monaco', 'Mongolia', 'Montenegro', 'Morocco', 'Netherlands',
#        'New Zealand', 'Nigeria', 'North Macedonia', 'Norway', 'Pakistan',
#        'People's Republic of China', 'Peru', 'Philippines', 'Poland',
# ...

# %%
df_final.shape
# Out:
# (92, 15)

# %%
for i in range(len(list(generos_atletas.index)):
        df_final["Total de atletas"][list(generos_atletas.index)[i]]=generos_atletas["Totales"][list(generos_atletas.index)[i]]

               df_final
# Out:
#   Input In [146]
#     for i in range(len(list(generos_atletas.index)):
#                                                    ^
# SyntaxError: invalid syntax

# %%
paises_totales
# Out:
# ['Albania',
#  'American Samoa',
#  'Andorra',
#  'Argentina',
#  'Armenia',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Belarus',
#  'Belgium',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Brazil',
#  'Bulgaria',
#  'Canada',
#  'Chile',
#  'Chinese Taipei',
#  'Colombia',
#  'Croatia',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'Ecuador',
#  'Eritrea',
#  'Estonia',
#  'Finland',
#  'France',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Great Britain',
#  'Greece',
#  'Haiti',
#  'Hong Kong, China',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Ireland',
#  'Islamic Republic of Iran',
#  'Israel',
#  'Italy',
#  'Jamaica',
#  'Japan',
#  'Kazakhstan',
#  'Kosovo',
#  'Kyrgyzstan',
#  'LBN',
#  'Latvia',
#  'Liechtenstein',
#  'Lithuania',
#  'Luxembourg',
#  'Madagascar',
#  'Malaysia',
#  'Malta',
#  'Mexico',
#  'Monaco',
#  'Mongolia',
#  'Montenegro',
#  'Morocco',
#  'Netherlands',
#  'New Zealand',
#  'Nigeria',
#  'North Macedonia',
#  'Norway',
#  'Pakistan',
# ...

# %%
country = pd.DataFrame(index = list(set(list(df_athletes["country"].unique())+list(df_coaches["country"].unique())+list(df_technical_officials["country"].unique()))))

# %%
paises_totales = list(country.index)

# %%
paises_totales.sort()

# %%
paises_totales
# Out:
# ['Albania',
#  'American Samoa',
#  'Andorra',
#  'Argentina',
#  'Armenia',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Belarus',
#  'Belgium',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Brazil',
#  'Bulgaria',
#  'Canada',
#  'Chile',
#  'Chinese Taipei',
#  'Colombia',
#  'Croatia',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'Ecuador',
#  'Eritrea',
#  'Estonia',
#  'Finland',
#  'France',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Great Britain',
#  'Greece',
#  'Haiti',
#  'Hong Kong, China',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Ireland',
#  'Islamic Republic of Iran',
#  'Israel',
#  'Italy',
#  'Jamaica',
#  'Japan',
#  'Kazakhstan',
#  'Kosovo',
#  'Kyrgyzstan',
#  'LBN',
#  'Latvia',
#  'Liechtenstein',
#  'Lithuania',
#  'Luxembourg',
#  'Madagascar',
#  'Malaysia',
#  'Malta',
#  'Mexico',
#  'Monaco',
#  'Mongolia',
#  'Montenegro',
#  'Morocco',
#  'Netherlands',
#  'New Zealand',
#  'Nigeria',
#  'North Macedonia',
#  'Norway',
#  'Pakistan',
# ...

# %%
list(generos_atletas.index) == paises_totales
# Out:
# False

# %%
a = set(paises_totales)
b = set(list(generos_atletas.index))
c = a.difference(b)

# %%
c
# Out:
# {'Russian Federation'}

# %%
for p in paises_totales:
    if p != 'Russian Federation':
        df_final["Total de atletas"][p]=generos_atletas["Totales"][p]
    else:
        df_final["Total de atletas"][p]= 0
df_final
# Out:
#                          Total de atletas Total de Atletas hombres  \
# Albania                                 1                      NaN
# American Samoa                          1                      NaN
# Andorra                                 5                      NaN
# Argentina                               6                      NaN
# Armenia                                 6                      NaN
# ...                                   ...                      ...
# Turkey                                  7                      NaN
# Ukraine                                46                      NaN
# United States of America              225                      NaN
# Uzbekistan                              1                      NaN
# Virgin Islands, US                      1                      NaN
#
#                          Total de Atletas mujeres Male coaches Female coaches  \
# Albania                                       NaN          NaN            NaN
# ...

# %%
for p in paises_totales:
    if p != 'Russian Federation':
        df_final["Total de Atletas hombres"][p]=generos_atletas["M"][p]
    else:
        df_final["Total de Atletas hombres"][p]= 0
df_final
# Out:
#                          Total de atletas Total de Atletas hombres  \
# Albania                                 1                        1
# American Samoa                          1                        1
# Andorra                                 5                        2
# Argentina                               6                        2
# Armenia                                 6                        3
# ...                                   ...                      ...
# Turkey                                  7                        4
# Ukraine                                46                       24
# United States of America              225                      117
# Uzbekistan                              1                        1
# Virgin Islands, US                      1                        0
#
#                          Total de Atletas mujeres Male coaches Female coaches  \
# Albania                                       NaN          NaN            NaN
# ...

# %%
for p in paises_totales:
    if p != 'Russian Federation':
        df_final["Total de Atletas mujeres"][p]=generos_atletas["F"][p]
    else:
        df_final["Total de Atletas mujeres"][p]= 0
df_final
# Out:
#                          Total de atletas Total de Atletas hombres  \
# Albania                                 1                        1
# American Samoa                          1                        1
# Andorra                                 5                        2
# Argentina                               6                        2
# Armenia                                 6                        3
# ...                                   ...                      ...
# Turkey                                  7                        4
# Ukraine                                46                       24
# United States of America              225                      117
# Uzbekistan                              1                        1
# Virgin Islands, US                      1                        0
#
#                          Total de Atletas mujeres Male coaches Female coaches  \
# Albania                                         0          NaN            NaN
# ...

# %%
generos_coaches
# Out:
# gender                      Female  Male  Totales
# country
# Australia                        0     1        1
# Canada                           1     6        7
# Czech Republic                   0     3        3
# Denmark                          3     6        9
# Finland                          1     2        3
# Germany                          0     2        2
# Great Britain                    0     4        4
# Italy                            0     3        3
# Japan                            0     3        3
# Latvia                           0     1        1
# Norway                           0     4        4
# People's Republic of China       0     7        7
# ROC                              0     4        4
# Republic of Korea                0     1        1
# Slovakia                         0     1        1
# Sweden                           1     7        8
# Switzerland                      0    11       11
# United States of America         1     4        5

# %%
a = set(paises_totales)
b= set(list(generos_coaches.index))
c = a.difference(b)
c
# Out:
# {'Albania',
#  'American Samoa',
#  'Andorra',
#  'Argentina',
#  'Armenia',
#  'Austria',
#  'Azerbaijan',
#  'Belarus',
#  'Belgium',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Brazil',
#  'Bulgaria',
#  'Chile',
#  'Chinese Taipei',
#  'Colombia',
#  'Croatia',
#  'Cyprus',
#  'Ecuador',
#  'Eritrea',
#  'Estonia',
#  'France',
#  'Georgia',
#  'Ghana',
#  'Greece',
#  'Haiti',
#  'Hong Kong, China',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Ireland',
#  'Islamic Republic of Iran',
#  'Israel',
#  'Jamaica',
#  'Kazakhstan',
#  'Kosovo',
#  'Kyrgyzstan',
#  'LBN',
#  'Liechtenstein',
#  'Lithuania',
#  'Luxembourg',
#  'Madagascar',
#  'Malaysia',
#  'Malta',
#  'Mexico',
#  'Monaco',
#  'Mongolia',
#  'Montenegro',
#  'Morocco',
#  'Netherlands',
#  'New Zealand',
#  'Nigeria',
#  'North Macedonia',
#  'Pakistan',
#  'Peru',
#  'Philippines',
#  'Poland',
#  'Portugal',
#  'Puerto Rico',
#  'Republic of Moldova',
#  'Romania',
#  'Russian Federation',
#  'San Marino',
# ...

# %%
df_final.columns
# Out:
# Index(['Total de atletas', 'Total de Atletas hombres',
#        'Total de Atletas mujeres', 'Male coaches', 'Female coaches',
#        'Male Officials', 'Female Officials', 'Male Total Medals',
#        'Femal Total Medals', 'Male Gold', 'Male Silver', 'Male Bronce',
#        'Female Gold', 'Female Silver', 'Female Brone'],
#       dtype='object')

# %%
si_esta = list(b)
no_esta = list (c)

for pais in si_esta:
    df_final["Male coaches"][pais]=generos_coaches["Male"][pais]
    
for pais in no_esta:
    df_final["Male coaches"][pais]=0

df_final
# Out:
#                          Total de atletas Total de Atletas hombres  \
# Albania                                 1                        1
# American Samoa                          1                        1
# Andorra                                 5                        2
# Argentina                               6                        2
# Armenia                                 6                        3
# ...                                   ...                      ...
# Turkey                                  7                        4
# Ukraine                                46                       24
# United States of America              225                      117
# Uzbekistan                              1                        1
# Virgin Islands, US                      1                        0
#
#                          Total de Atletas mujeres Male coaches Female coaches  \
# Albania                                         0            0            NaN
# ...

# %%
for pais in si_esta:
    df_final["Female coaches"][pais]=generos_coaches["Female"][pais]
    
for pais in no_esta:
    df_final["Female coaches"][pais]=0

df_final
# Out:
#                          Total de atletas Total de Atletas hombres  \
# Albania                                 1                        1
# American Samoa                          1                        1
# Andorra                                 5                        2
# Argentina                               6                        2
# Armenia                                 6                        3
# ...                                   ...                      ...
# Turkey                                  7                        4
# Ukraine                                46                       24
# United States of America              225                      117
# Uzbekistan                              1                        1
# Virgin Islands, US                      1                        0
#
#                          Total de Atletas mujeres Male coaches Female coaches  \
# Albania                                         0            0              0
# ...

# %%
generos_tecnicos
# Out:
# gender                      Female  Male  Totales
# country
# Austria                          1     1        2
# Belarus                          1     0        1
# Canada                           4     0        4
# Czech Republic                   1     1        2
# Estonia                          2     0        2
# Finland                          2     1        3
# France                           0     2        2
# Germany                          2     1        3
# Great Britain                    1     1        2
# Hungary                          1     0        1
# Israel                           1     1        2
# Italy                            2     2        4
# Japan                            3     1        4
# Latvia                           1     0        1
# Lithuania                        1     0        1
# Mexico                           1     0        1
# Netherlands                      1     1        2
# People's Republic of China       3     1        4
# ...

# %%
a = set(paises_totales)
b= set(list(generos_tecnicos.index))
c = a.difference(b)
c
# Out:
# {'Albania',
#  'American Samoa',
#  'Andorra',
#  'Argentina',
#  'Armenia',
#  'Australia',
#  'Azerbaijan',
#  'Belgium',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Brazil',
#  'Bulgaria',
#  'Chile',
#  'Chinese Taipei',
#  'Colombia',
#  'Croatia',
#  'Cyprus',
#  'Denmark',
#  'Ecuador',
#  'Eritrea',
#  'Georgia',
#  'Ghana',
#  'Greece',
#  'Haiti',
#  'Hong Kong, China',
#  'Iceland',
#  'India',
#  'Ireland',
#  'Islamic Republic of Iran',
#  'Jamaica',
#  'Kazakhstan',
#  'Kosovo',
#  'Kyrgyzstan',
#  'LBN',
#  'Liechtenstein',
#  'Luxembourg',
#  'Madagascar',
#  'Malaysia',
#  'Malta',
#  'Monaco',
#  'Mongolia',
#  'Montenegro',
#  'Morocco',
#  'New Zealand',
#  'Nigeria',
#  'North Macedonia',
#  'Norway',
#  'Pakistan',
#  'Peru',
#  'Philippines',
#  'Portugal',
#  'Puerto Rico',
#  'ROC',
#  'Republic of Moldova',
#  'Romania',
#  'San Marino',
#  'Saudi Arabia',
#  'Serbia',
#  'Slovakia',
#  'Slovenia',
#  'Switzerland',
#  'Thailand',
#  'Timor-Leste',
# ...

# %%
df_final.columns
# Out:
# Index(['Total de atletas', 'Total de Atletas hombres',
#        'Total de Atletas mujeres', 'Male coaches', 'Female coaches',
#        'Male Officials', 'Female Officials', 'Male Total Medals',
#        'Femal Total Medals', 'Male Gold', 'Male Silver', 'Male Bronce',
#        'Female Gold', 'Female Silver', 'Female Brone'],
#       dtype='object')

# %%
si_esta = list(b)
no_esta = list (c)

for pais in si_esta:
    df_final["Female Officials"][pais]=generos_tecnicos["Female"][pais]
    df_final["Male Officials"][pais]=generos_tecnicos["Male"][pais]
    
for pais in no_esta:
    df_final["Female Officials"][pais]=0
    df_final["Male Officials"]=0

df_final
# Out:
# /var/folders/m5/cfc15px573ld6bgr5zly12_m0000gn/T/ipykernel_3803/4035192730.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["Female Officials"][pais]=0
#                          Total de atletas Total de Atletas hombres  \
# Albania                                 1                        1
# American Samoa                          1                        1
# Andorra                                 5                        2
# Argentina                               6                        2
# Armenia                                 6                        3
# ...                                   ...                      ...
# Turkey                                  7                        4
# Ukraine                                46                       24
# ...

# %%
df_medallas_hombre
# Out:
# medal_code                   1   2   3
# country_atletas
# Australia                    0   1   0
# Austria                     11   6   4
# Belarus                      0   1   0
# Belgium                      1   0   0
# Canada                       6   4  18
# Finland                     26   2   1
# France                       4   8   5
# Germany                     14  16   7
# Great Britain                0   5   0
# Hungary                      1   0   4
# Italy                        1   5   7
# Japan                        2   2  12
# Latvia                       0   0   3
# Netherlands                  2   3   0
# New Zealand                  1   0   0
# Norway                      21  10  12
# People's Republic of China   7   4   1
# Poland                       0   0   1
# ROC                          9  36  15
# Republic of Korea            1   7   2
# Slovakia                     0   0  25
# Slovenia                     2   6   0
# ...

# %%
a = set(paises_totales)
b= set(list(df_medallas_hombre.index))
c = a.difference(b)
c
# Out:
# {'Albania',
#  'American Samoa',
#  'Andorra',
#  'Argentina',
#  'Armenia',
#  'Azerbaijan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Brazil',
#  'Bulgaria',
#  'Chile',
#  'Chinese Taipei',
#  'Colombia',
#  'Croatia',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'Ecuador',
#  'Eritrea',
#  'Estonia',
#  'Georgia',
#  'Ghana',
#  'Greece',
#  'Haiti',
#  'Hong Kong, China',
#  'Iceland',
#  'India',
#  'Ireland',
#  'Islamic Republic of Iran',
#  'Israel',
#  'Jamaica',
#  'Kazakhstan',
#  'Kosovo',
#  'Kyrgyzstan',
#  'LBN',
#  'Liechtenstein',
#  'Lithuania',
#  'Luxembourg',
#  'Madagascar',
#  'Malaysia',
#  'Malta',
#  'Mexico',
#  'Monaco',
#  'Mongolia',
#  'Montenegro',
#  'Morocco',
#  'Nigeria',
#  'North Macedonia',
#  'Pakistan',
#  'Peru',
#  'Philippines',
#  'Portugal',
#  'Puerto Rico',
#  'Republic of Moldova',
#  'Romania',
#  'Russian Federation',
#  'San Marino',
#  'Saudi Arabia',
#  'Serbia',
#  'Spain',
#  'Thailand',
#  'Timor-Leste',
# ...

# %%
df_final.columns
# Out:
# Index(['Total de atletas', 'Total de Atletas hombres',
#        'Total de Atletas mujeres', 'Male coaches', 'Female coaches',
#        'Male Officials', 'Female Officials', 'Male Total Medals',
#        'Femal Total Medals', 'Male Gold', 'Male Silver', 'Male Bronce',
#        'Female Gold', 'Female Silver', 'Female Brone'],
#       dtype='object')

# %%
si_esta = list(b)
no_esta = list (c)

for pais in si_esta:
    df_final["Male Gold"][pais]=df_medallas_hombre[1][pais]
    df_final["Male Silver"][pais]=df_medallas_hombre[2][pais]
    df_final["Male Bronce"][pais]=df_medallas_hombre[3][pais]
    
for pais in no_esta:
    df_final["Male Gold"][pais]=0
    df_final["Male Silver"][pais]=0
    df_final["Male Bronce"][pais]=0

df_final
# Out:
# /var/folders/m5/cfc15px573ld6bgr5zly12_m0000gn/T/ipykernel_3803/3317672791.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["Male Gold"][pais]=df_medallas_hombre[1][pais]
# /var/folders/m5/cfc15px573ld6bgr5zly12_m0000gn/T/ipykernel_3803/3317672791.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["Male Silver"][pais]=df_medallas_hombre[2][pais]
# /var/folders/m5/cfc15px573ld6bgr5zly12_m0000gn/T/ipykernel_3803/3317672791.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df_final["Male Total Medals"] = df_final["Male Gold"]+df_final["Male Silver"]+df_final["Male Bronce"]
df_final
# Out:
#                          Total de atletas Total de Atletas hombres  \
# Albania                                 1                        1
# American Samoa                          1                        1
# Andorra                                 5                        2
# Argentina                               6                        2
# Armenia                                 6                        3
# ...                                   ...                      ...
# Turkey                                  7                        4
# Ukraine                                46                       24
# United States of America              225                      117
# Uzbekistan                              1                        1
# Virgin Islands, US                      1                        0
#
#                          Total de Atletas mujeres Male coaches Female coaches  \
# Albania                                         0            0              0
# ...

# %%
df_medallas_mujer
# Out:
# medal_code                   1   2   3
# country_atletas
# Australia                    1   1   1
# Austria                      4   4   1
# Belarus                      0   1   0
# Belgium                      0   0   1
# Canada                      26   4   9
# Czech Republic               1   0   1
# Estonia                      0   0   1
# Finland                      0   1  25
# France                       2   5   0
# Germany                      8  10   5
# Great Britain                5   0   0
# Hungary                      0   0   2
# Italy                        2   8   4
# Japan                        1  10   7
# Latvia                       0   0   1
# Netherlands                  9   2   7
# New Zealand                  1   1   0
# Norway                       7   2   6
# People's Republic of China   7   2   5
# ROC                          8  10   8
# Republic of Korea            1   5   0
# Slovakia                     1   0   0
# ...

# %%
a = set(paises_totales)
b= set(list(df_medallas_mujer.index))
c = a.difference(b)


si_esta = list(b)
no_esta = list (c)

for pais in si_esta:
    df_final["Female Gold"][pais]=df_medallas_mujer[1][pais]
    df_final["Female Silver"][pais]=df_medallas_mujer[2][pais]
    df_final["Female Brone"][pais]=df_medallas_mujer[3][pais]
    
for pais in no_esta:
    df_final["Female Gold"][pais]=0
    df_final["Female Silver"][pais]=0
    df_final["Female Brone"][pais]=0
    
df_final["Female Total Medals"] = df_final["Female Gold"]+df_final["Female Silver"]+df_final["Female Brone"]
df_final
# Out:
# /var/folders/m5/cfc15px573ld6bgr5zly12_m0000gn/T/ipykernel_3803/1804087398.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["Female Gold"][pais]=df_medallas_mujer[1][pais]
# /var/folders/m5/cfc15px573ld6bgr5zly12_m0000gn/T/ipykernel_3803/1804087398.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["Female Silver"][pais]=df_medallas_mujer[2][pais]
# /var/folders/m5/cfc15px573ld6bgr5zly12_m0000gn/T/ipykernel_3803/1804087398.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df_final.columns
# Out:
# Index(['Total de atletas', 'Total de Atletas hombres',
#        'Total de Atletas mujeres', 'Male coaches', 'Female coaches',
#        'Male Officials', 'Female Officials', 'Male Total Medals',
#        'Femal Total Medals', 'Male Gold', 'Male Silver', 'Male Bronce',
#        'Female Gold', 'Female Silver', 'Female Brone', 'Female Total Medals'],
#       dtype='object')

# %%
df_final_verdadero=df_final[['Total de atletas', 'Total de Atletas hombres',
       'Total de Atletas mujeres', 'Male coaches', 'Female coaches',
       'Male Officials', 'Female Officials', 'Male Total Medals']]

# %%
df_final_verdadero["Female Total Medals"]=df_final["Female Total Medals"]
df_final_verdadero['Male Gold']=df_final['Male Gold']
df_final_verdadero['Male Silver']=df_final['Male Silver']
df_final_verdadero['Male Bronce']=df_final['Male Bronce']
df_final_verdadero['Female Gold']=df_final['Female Gold']
df_final_verdadero['Female Silver']=df_final['Female Silver']
df_final_verdadero['Female Bronce']=df_final['Female Brone']
df_final_verdadero
# Out:
# /var/folders/m5/cfc15px573ld6bgr5zly12_m0000gn/T/ipykernel_3803/3316712763.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final_verdadero["Female Total Medals"]=df_final["Female Total Medals"]
# /var/folders/m5/cfc15px573ld6bgr5zly12_m0000gn/T/ipykernel_3803/3316712763.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final_verdadero['Male Gold']=df_final['Male Gold']
# /var/folders/m5/cfc15px573ld6bgr5zly12_m0000gn/T/ipykernel_3803/3316712763.py:3: SettingWithCopyWarning:
# ...

# %%
path = "/Users/jesusarredondo/Documents/Diplomado/Modulo1/Data/"
nombre = "Equipo3.csv"
df_final_verdadero.to_csv(path+nombre, encoding = "utf-8")
